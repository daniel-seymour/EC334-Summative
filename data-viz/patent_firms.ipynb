# %%
# Import necessary libraries
import pandas as pd

# Read the Excel file
file_path = '../data/bds2022_pfg_utly_sec.csv'
patent_firms_df = pd.read_csv(file_path)

# %%
patent_firms_df.head(10)
# Out:
#    year                   pfg_utly sector   firms  estabs      emp    denom  \
# 0  1978  No Utility Patent Granted     11   20273   20612   158446   152276
# 1  1978  No Utility Patent Granted     21   18783   21165   388476   379710
# 2  1978  No Utility Patent Granted     22    5606   10439   577064   561665
# 3  1978  No Utility Patent Granted     23  425719  429676  3763792  3495877
# 4  1978  No Utility Patent Granted  31-33  256922  277121  8097426  7813994
# 5  1978  No Utility Patent Granted     42  233323  270748  2974362  2868181
# 6  1978  No Utility Patent Granted  44-45  740523  936274  8742433  8463565
# 7  1978  No Utility Patent Granted  48-49   89565  103937  1988676  1910460
# 8  1978  No Utility Patent Granted     51   38144   49050  1099730  1063397
# 9  1978  No Utility Patent Granted     52  146025  219631  3753638  3643840
#
#   estabs_entry estabs_entry_rate  estabs_exit  ...  job_destruction_deaths  \
# ...

# %%
patent_firms_df.columns
# Out:
# Index(['year', 'pfg_utly', 'sector', 'firms', 'estabs', 'emp', 'denom',
#        'estabs_entry', 'estabs_entry_rate', 'estabs_exit', 'estabs_exit_rate',
#        'job_creation', 'job_creation_births', 'job_creation_continuers',
#        'job_creation_rate_births', 'job_creation_rate', 'job_destruction',
#        'job_destruction_deaths', 'job_destruction_continuers',
#        'job_destruction_rate_deaths', 'job_destruction_rate',
#        'net_job_creation', 'net_job_creation_rate', 'reallocation_rate',
#        'firmdeath_firms', 'firmdeath_estabs', 'firmdeath_emp'],
#       dtype='object')

# %%
patent_firms_df['pfg_utly'].unique()
# Out:
# array(['No Utility Patent Granted', 'Utility Patent Granted'],
#       dtype=object)

# %%
dd

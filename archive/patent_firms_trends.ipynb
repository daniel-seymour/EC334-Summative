# %%
import pandas as pd

df = pd.read_csv('/Users/danielseymour/Developer/EC334-Summative/raw_data/dynamism_data/bds2022_pfg_utly_sec.csv')
df.head()
# Out:
#    year                   pfg_utly sector   firms  estabs      emp    denom  \
# 0  1978  No Utility Patent Granted     11   20273   20612   158446   152276
# 1  1978  No Utility Patent Granted     21   18783   21165   388476   379710
# 2  1978  No Utility Patent Granted     22    5606   10439   577064   561665
# 3  1978  No Utility Patent Granted     23  425719  429676  3763792  3495877
# 4  1978  No Utility Patent Granted  31-33  256922  277121  8097426  7813994
#
#   estabs_entry estabs_entry_rate  estabs_exit  ...  job_destruction_deaths  \
# 0         3975            19.425         3677  ...                   17161
# 1         3546            17.052         2806  ...                   36199
# 2          857             8.356          492  ...                   10767
# 3        91637            22.236        56514  ...                  259043
# 4        32100            11.728        25256  ...                  359056
#
# ...

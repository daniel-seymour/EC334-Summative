# %%
import sys, os

# get the absolute path to the repo root
repo_root = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
sys.path.insert(0, repo_root)

from utils import save_fig, save_df

import pandas as pd # type: ignore
import matplotlib.pyplot as plt # type: ignore

# %%
import sys
import subprocess
subprocess.check_call([sys.executable, "-m", "pip", "install", "openpyxl"])
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 25.1.1 is available.
# You should consider upgrading via the '/Users/danielseymour/Developer/EC334-Summative/.venv/bin/python -m pip install --upgrade pip' command.
# 0

# %%
# Import necessary libraries
import pandas as pd

# Read the Excel file
file_path = '/Users/danielseymour/Developer/EC334-Summative/raw_data/productivity_data/major-industry-total-factor-productivity-klems.xlsx'
sectoral_tfp_df = pd.read_excel(file_path, skiprows=2)

# %%
sectoral_tfp_df.tail(80)
# Out:
#      NAICS                           Industry        Basis  \
# 7210    81  Other services, except government  All workers
# 7211    81  Other services, except government  All workers
# 7212    81  Other services, except government  All workers
# 7213    81  Other services, except government  All workers
# 7214    81  Other services, except government  All workers
# ...    ...                                ...          ...
# 7285    81  Other services, except government  All workers
# 7286    81  Other services, except government  All workers
# 7287    81  Other services, except government  All workers
# 7288    81  Other services, except government  All workers
# 7289    81  Other services, except government  All workers
#
#                              Measure             Units    1987    1988  \
# 7210             Intermediate inputs  Index (2017=100)   41.62  45.188
# 7211                    Energy input  Index (2017=100)  90.843  96.795
# ...

# %%
sectoral_tfp_df.shape
# Out:
# (7290, 42)

# %%
sectoral_tfp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7290 entries, 0 to 7289
# Data columns (total 42 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NAICS     7290 non-null   object
#  1   Industry  7290 non-null   object
#  2   Basis     7290 non-null   object
#  3   Measure   7290 non-null   object
#  4   Units     7290 non-null   object
#  5   1987      7290 non-null   object
#  6   1988      7290 non-null   object
#  7   1989      7290 non-null   object
#  8   1990      7290 non-null   object
#  9   1991      7290 non-null   object
#  10  1992      7290 non-null   object
#  11  1993      7290 non-null   object
#  12  1994      7290 non-null   object
#  13  1995      7290 non-null   object
#  14  1996      7290 non-null   object
#  15  1997      7290 non-null   object
#  16  1998      7290 non-null   object
#  17  1999      7290 non-null   object
#  18  2000      7290 non-null   object
#  19  2001      7290 non-null   object
# ...

# %%
sectoral_tfp_df['NAICS'].unique()
# Out:
# array(['11', '111-112', '113-115', '21', '211', '212', '213', '22', '23',
#        'MN', 'DM', 'ND', '321', '327', '331', '332', '333', '334', '335',
#        '3361-3363', '3364-3369', '337', '339', '311-312', '313-314',
#        '315-316', '322', '323', '324', '325', '326', '42,44-45', '42',
#        '44,45', '48-49', '481', '482', '483', '484', '485', '486',
#        '487,488,492', '493', '51', '511', '512', '515,517', '518-519',
#        '52-53', '52', '521-522', '523', '524', '525', '53', '531',
#        '532-533', '54-81', '54-56', '54', '5411', '5415',
#        '5412-5414,5416-5419', '55', '56', '561', '562', '61-62', '61',
#        '62', '621', '622-623', '624', '71-72', '71', '711-712', '713',
#        '72', '721', '722', '81'], dtype=object)
